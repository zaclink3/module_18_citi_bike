# %%
import pandas as pd
import glob

# create a list of all CSV files in a folder
path = '*.csv'
files = glob.glob(path)

# create an empty list to store the data frames
dfs = []

# loop through each CSV file and append it to the list of data frames
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)

# concatenate all data frames in the list into a single data frame
stacked_df = pd.concat(dfs)
# Out:
# /var/folders/rm/t4jzkgwj1ks952zpfq0w7hf00000gn/T/ipykernel_82073/1148573321.py:13: DtypeWarning: Columns (14,15,17,21,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)

# %%
stacked_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  ...  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411  ...
# ...

# %%
stacked_df['start station latitude'].isnull().sum()
# Out:
# 3397328

# %%
len(stacked_df)
# Out:
# 3420576

# %%
stacked_df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'tripduration', 'starttime', 'stoptime',
#        'start station id', 'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df = stacked_df.drop(['starttime','stoptime','start station id','start station name','start station latitude','start station longitude','end station id','end station name','end station latitude','end station longitude'], axis=1)

# %%
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
df = df.rename(columns={'start_lat':'start_latitude','start_lng':'start_longitude','end_lat':'end_latitude', 'end_lng':'end_longitude'})

# %%
df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_latitude  \
# 0  9 St HBLR - Jackson St & 8 St          HB305       40.747907
# 1  9 St HBLR - Jackson St & 8 St          HB305       40.747907
# ...

# %%
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_latitude        float64
# start_longitude       float64
# end_latitude          float64
# end_longitude         float64
# member_casual          object
# tripduration          float64
# bikeid                float64
# usertype               object
# birth year            float64
# gender                float64
# dtype: object

# %%
# save the stacked data frame to a new CSV file
df.to_csv('updated.csv', index=False)
